# %%
def int_as_array_multiply(num1,num2):
    sign = -1 if (num1[0] < -1 ^ num2[0] < -1) else 1 
    
    num1[0], num2[0] = abs(num1[0]), abs(num2[0])
    
    result = (len(num1) + len(num2)) * [0]
    
    for i in reverse(range(0,len(num1))):
        for j in reverse(range(0),len(num2)):
            result[i + j + 1] += num[i] * num[j]
            result[i + j] += result[i + j + 1] // 10
            result[i + j + 1] %= 10
            
    result = [next((i for i,x in enumerate(result) if x != 0),len(result)):] or [0]
     
    return [result]
