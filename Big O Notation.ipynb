# %% [markdown]
# O(n^2): Double for loops. Runs n * n times.
# O(n^n): Same logic as O(n^2).
# O(logn): Number^Number = Some numner. Always 2 in Comp Sci.
#     Binary Search: Only works with ordered array.
#     1. Find midpoint
#     2. Split array
#     3. Afer reducing the array you are left with an endpoint.
#     Completed recursively.
# O(nlogn):
#     MergeSort:
#     1.Split array in two
#     2.Create a merger helper function that sorts them and brings  them together.
#     3.Set the recursion with returning the helper function with the mergesort on both ends.
#     There are log n levels to the tree structure with n steps at each level thus O(nlogn).
# O(2^n):
#     Fibonacci Function:
#     Each level is a pattern of 2^n as the level increases.
# O(n!):
# The total number of times ran at the last level is n!. First level n. Second level n(n-1).. till the last level of n!.
#
# Space Complexity
# Each call takes space on the call stack. If there are n calls then it is O(n).
